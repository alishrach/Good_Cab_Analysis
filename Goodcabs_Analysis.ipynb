# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#Contains detailed information about each individual trip
trip_summary=pd.read_csv('/content/fact_trips.csv')
display(trip_summary)
# Out:
#                      trip_id        date city_id passenger_type  \
# 0       TRPLUC240113d55de2fb  2024-01-13    UP01       repeated
# 1       TRPVAD240129a3b6dba8  2024-01-29    GJ02       repeated
# 2       TRPCOI240107a42430fb  2024-01-07    TN01       repeated
# 3       TRPKOC240325d7601389  2024-03-25    KL01       repeated
# 4       TRPVIS2406027be97166  2024-06-02    AP01            new
# ...                      ...         ...     ...            ...
# 425898  TRPLUC2403180b02b4d0  2024-03-18    UP01       repeated
# 425899  TRPVAD2401032679e669  2024-01-03    GJ02       repeated
# 425900  TRPJAI24022578e10280  2024-02-25    RJ01       repeated
# 425901  TRPJAI240401e297ad20  2024-04-01    RJ01       repeated
# 425902  TRPJAI24021056f0e951  2024-02-10    RJ01            new
#
#         distance_travelled(km)  fare_amount  passenger_rating  driver_rating
# 0                           11          158                 5              5
# ...

# %%
#provides details about the cities in which Goodcabs operates
city=pd.read_csv('/content/dim_city.csv')
display(city)
# Out:
#   city_id      city_name
# 0    RJ01         Jaipur
# 1    UP01        Lucknow
# 2    GJ01          Surat
# 3    KL01          Kochi
# 4    MP01         Indore
# 5    CH01     Chandigarh
# 6    GJ02       Vadodara
# 7    AP01  Visakhapatnam
# 8    TN01     Coimbatore
# 9    KA01         Mysore

# %%
trip_details=trip_summary.merge(city,on='city_id',how='left')
display(trip_details)
# Out:
#                      trip_id        date city_id passenger_type  \
# 0       TRPLUC240113d55de2fb  2024-01-13    UP01       repeated
# 1       TRPVAD240129a3b6dba8  2024-01-29    GJ02       repeated
# 2       TRPCOI240107a42430fb  2024-01-07    TN01       repeated
# 3       TRPKOC240325d7601389  2024-03-25    KL01       repeated
# 4       TRPVIS2406027be97166  2024-06-02    AP01            new
# ...                      ...         ...     ...            ...
# 425898  TRPLUC2403180b02b4d0  2024-03-18    UP01       repeated
# 425899  TRPVAD2401032679e669  2024-01-03    GJ02       repeated
# 425900  TRPJAI24022578e10280  2024-02-25    RJ01       repeated
# 425901  TRPJAI240401e297ad20  2024-04-01    RJ01       repeated
# 425902  TRPJAI24021056f0e951  2024-02-10    RJ01            new
#
#         distance_travelled(km)  fare_amount  passenger_rating  driver_rating  \
# 0                           11          158                 5              5
# ...

# %%
dim_date_df=pd.read_csv('/content/dim_date.csv')
display(dim_date_df)
# Out:
#            date start_of_month month_name day_type
# 0    2024-01-01     2024-01-01    January  Weekday
# 1    2024-01-02     2024-01-01    January  Weekday
# 2    2024-01-03     2024-01-01    January  Weekday
# 3    2024-01-04     2024-01-01    January  Weekday
# 4    2024-01-05     2024-01-01    January  Weekday
# ..          ...            ...        ...      ...
# 177  2024-06-26     2024-06-01       June  Weekday
# 178  2024-06-27     2024-06-01       June  Weekday
# 179  2024-06-28     2024-06-01       June  Weekday
# 180  2024-06-29     2024-06-01       June  Weekend
# 181  2024-06-30     2024-06-01       June  Weekend
#
# [182 rows x 4 columns]

# %%
#To understand how often passengers are taking repeat trips in each city
repeat_trip=pd.read_csv('/content/dim_repeat_trip_distribution.csv')
display(repeat_trip)
# Out:
#           month city_id trip_count  repeat_passenger_count
# 0    2024-01-01    AP01   10-Trips                       7
# 1    2024-01-01    AP01    2-Trips                     352
# 2    2024-01-01    AP01    3-Trips                     158
# 3    2024-01-01    AP01    4-Trips                      53
# 4    2024-01-01    AP01    5-Trips                      38
# ..          ...     ...        ...                     ...
# 535  2024-06-01    UP01    5-Trips                     272
# 536  2024-06-01    UP01    6-Trips                     272
# 537  2024-06-01    UP01    7-Trips                     246
# 538  2024-06-01    UP01    8-Trips                      83
# 539  2024-06-01    UP01    9-Trips                      19
#
# [540 rows x 4 columns]

# %%
passenger=pd.read_csv('/content/fact_passenger_summary.csv')
display(passenger)
# Out:
#          month city_id  new_passengers  repeat_passengers  total_passengers
# 0   2024-01-01    AP01            2513                650              3163
# 1   2024-01-01    CH01            3920                720              4640
# 2   2024-01-01    GJ01            2432               1184              3616
# 3   2024-01-01    GJ02            2089                544              2633
# 4   2024-01-01    KA01            1957                172              2129
# 5   2024-01-01    KL01            4865                795              5660
# 6   2024-01-01    MP01            2843               1033              3876
# 7   2024-01-01    RJ01           10423               1422             11845
# 8   2024-01-01    TN01            1822                392              2214
# 9   2024-01-01    UP01            3465               1431              4896
# 10  2024-02-01    AP01            2380                790              3170
# ...

# %%
#Holds monthly targets for acquiring new passengers in each city
target_passengers=pd.read_csv('/content/monthly_target_new_passengers.csv')
display(target_passengers)
# Out:
#          month city_id  target_new_passengers
# 0   2024-05-01    GJ01                   1500
# 1   2024-05-01    GJ02                   1500
# 2   2024-03-01    GJ01                   2000
# 3   2024-05-01    UP01                   2000
# 4   2024-05-01    MP01                   2000
# 5   2024-01-01    AP01                   2500
# 6   2024-03-01    MP01                   2700
# 7   2024-06-01    CH01                   3000
# 8   2024-04-01    AP01                   2000
# 9   2024-01-01    KA01                   2000
# 10  2024-03-01    UP01                   3200
# 11  2024-02-01    AP01                   2500
# 12  2024-04-01    GJ02                   1500
# 13  2024-02-01    TN01                   1500
# 14  2024-01-01    MP01                   2700
# 15  2024-03-01    TN01                   1500
# 16  2024-05-01    KA01                   2000
# 17  2024-05-01    TN01                   1000
# 18  2024-02-01    GJ01                   2000
# ...

# %%
#Contains monthly target data for the total number of trips in each city.
target_trips=pd.read_csv('/content/monthly_target_trips.csv')
display(target_trips)
# Out:
#          month city_id  total_target_trips
# 0   2024-03-01    MP01                7000
# 1   2024-05-01    KA01                2500
# 2   2024-04-01    UP01               11000
# 3   2024-02-01    GJ02                6000
# 4   2024-05-01    KL01                9000
# 5   2024-02-01    UP01               13000
# 6   2024-01-01    AP01                4500
# 7   2024-01-01    CH01                7000
# 8   2024-02-01    KL01                7500
# 9   2024-03-01    UP01               13000
# 10  2024-02-01    TN01                3500
# 11  2024-06-01    KL01                9000
# 12  2024-04-01    KL01                9000
# 13  2024-04-01    KA01                2500
# 14  2024-06-01    GJ01               10000
# 15  2024-01-01    RJ01               13000
# 16  2024-05-01    CH01                6000
# 17  2024-03-01    KL01                7500
# 18  2024-04-01    MP01                7500
# 19  2024-05-01    RJ01                9500
# 20  2024-05-01    GJ02                6500
# ...

# %%
# Contains the target average passenger rating that Goodcabs aims to achieve for each city.
target_rating=pd.read_csv('/content/city_target_passenger_rating.csv')
display(target_rating)
# Out:
#   city_id  target_avg_passenger_rating
# 0    CH01                         8.00
# 1    UP01                         7.25
# 2    AP01                         8.50
# 3    MP01                         8.00
# 4    RJ01                         8.25
# 5    KA01                         8.50
# 6    GJ01                         7.00
# 7    TN01                         8.25
# 8    KL01                         8.50
# 9    GJ02                         7.50

# %% [markdown]
# **Top and Bottom Performing Cities By Total Trips**

# %%
total_trips_count=trip_summary.groupby('city_id')['trip_id'].count().reset_index()
total_trips_count
# Out:
#   city_id  trip_id
# 0    AP01    28366
# 1    CH01    38981
# 2    GJ01    54843
# 3    GJ02    32026
# 4    KA01    16238
# 5    KL01    50702
# 6    MP01    42456
# 7    RJ01    76888
# 8    TN01    21104
# 9    UP01    64299

# %%
total_trips_count.rename(columns={'trip_id':'total_trips'},inplace=True)

# %%
top_3_cities=total_trips_count.sort_values(by='total_trips',ascending=False).head(3)

# %%
bottom_3_cities=total_trips_count.sort_values(by='total_trips',ascending=True).head(3)

# %%
top_3_city=top_3_cities.merge(city,on='city_id',how='left')
bottom_3_city=bottom_3_cities.merge(city,on='city_id',how='left')

# %%
print("The top 3 cities with highest trip count:")
display(top_3_city)
# Out:
# The top 3 cities with highest trip count:
#   city_id  total_trips city_name
# 0    RJ01        76888    Jaipur
# 1    UP01        64299   Lucknow
# 2    GJ01        54843     Surat

# %%
print("The bottom 3 cities with lowest trip count:")
display(bottom_3_city)
# Out:
# The bottom 3 cities with lowest trip count:
#   city_id  total_trips      city_name
# 0    KA01        16238         Mysore
# 1    TN01        21104     Coimbatore
# 2    AP01        28366  Visakhapatnam

# %% [markdown]
# The analysis shows that **Jaipur** (76,888 trips), **Lucknow** (64,299 trips), and **Surat** (54,843 trips) are the top three cities with the **highest trip counts**, indicating high customer engagement and demand in these areas.
#
#  In contrast, the cities with the **lowest trip counts** are **Mysore** (16,238 trips), **Coimbatore** (21,104 trips), and **Visakhapatnam** (28,366 trips). These lower numbers could suggest lower demand or fewer operational resources in these regions, presenting opportunities for targeted promotions or service improvements to boost trip volume.

# %% [markdown]
# **Average Fare Per Trip By City**

# %%
#calculating average fare per trip
avg_fare_per_trip=trip_summary.groupby('city_id')['fare_amount'].mean().reset_index()
avg_fare_per_trip
# Out:
#   city_id  fare_amount
# 0    AP01   282.672284
# 1    CH01   283.686950
# 2    GJ01   117.272925
# 3    GJ02   118.566165
# 4    KA01   249.707168
# 5    KL01   335.245079
# 6    MP01   179.838609
# 7    RJ01   483.918128
# 8    TN01   166.982183
# 9    UP01   147.180376

# %%
#renaming the column for better readability
avg_fare_per_trip.rename(columns={'fare_amount':'avg_fare'},inplace=True)

# %%
#calculating average distance per trip
avg_distance_per_trip=trip_summary.groupby('city_id')['distance_travelled(km)'].mean().reset_index()
avg_distance_per_trip
# Out:
#   city_id  distance_travelled(km)
# 0    AP01               22.553938
# 1    CH01               23.518714
# 2    GJ01               10.997247
# 3    GJ02               11.517736
# 4    KA01               16.496921
# 5    KL01               24.065461
# 6    MP01               16.502473
# 7    RJ01               30.023125
# 8    TN01               14.979198
# 9    UP01               12.512963

# %%
avg_distance_per_trip.rename(columns={'distance_travelled(km)':'avg_distance'},inplace=True)

# %%
#merging the df based on 'city_id' to get the city names
avg_fare_and_dist=avg_fare_per_trip.merge(avg_distance_per_trip,on='city_id',how='inner')
display(avg_fare_and_dist)
# Out:
#   city_id    avg_fare  avg_distance
# 0    AP01  282.672284     22.553938
# 1    CH01  283.686950     23.518714
# 2    GJ01  117.272925     10.997247
# 3    GJ02  118.566165     11.517736
# 4    KA01  249.707168     16.496921
# 5    KL01  335.245079     24.065461
# 6    MP01  179.838609     16.502473
# 7    RJ01  483.918128     30.023125
# 8    TN01  166.982183     14.979198
# 9    UP01  147.180376     12.512963

# %%
avg_fare_dist=avg_fare_and_dist.merge(city,on='city_id',how='left')
display(avg_fare_dist)
# Out:
#   city_id    avg_fare  avg_distance      city_name
# 0    AP01  282.672284     22.553938  Visakhapatnam
# 1    CH01  283.686950     23.518714     Chandigarh
# 2    GJ01  117.272925     10.997247          Surat
# 3    GJ02  118.566165     11.517736       Vadodara
# 4    KA01  249.707168     16.496921         Mysore
# 5    KL01  335.245079     24.065461          Kochi
# 6    MP01  179.838609     16.502473         Indore
# 7    RJ01  483.918128     30.023125         Jaipur
# 8    TN01  166.982183     14.979198     Coimbatore
# 9    UP01  147.180376     12.512963        Lucknow

# %%
highest_fare_city = avg_fare_dist.loc[avg_fare_dist['avg_fare'].idxmax()]
lowest_fare_city = avg_fare_dist.loc[avg_fare_dist['avg_fare'].idxmin()]

print(f"City with the highest average fare per trip: \n{highest_fare_city}")
print(f"\n\nCity with the lowest average fare per trip: \n{lowest_fare_city}")
# Out:
# City with the highest average fare per trip:
# city_id               RJ01
# avg_fare        483.918128
# avg_distance     30.023125
# city_name           Jaipur
# Name: 7, dtype: object
#
#
# City with the lowest average fare per trip:
# city_id               GJ01
# avg_fare        117.272925
# avg_distance     10.997247
# city_name            Surat
# Name: 2, dtype: object

# %%
avg_fare_dist_melted = avg_fare_dist.melt(id_vars='city_name',
                                          value_vars=['avg_fare', 'avg_distance'],
                                          var_name='Metric', value_name='Value')

plt.figure(figsize=(12, 6))
sns.barplot(data=avg_fare_dist_melted, x='city_name', y='Value', hue='Metric')
plt.xlabel('City')
plt.ylabel('Values')
plt.title('Comparison of Avg Fare and Avg Distance by City')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Based on the cluster plot, Jaipur has the highest average fare( 483.918128) than compared to the other cities. Reasons could be higher demand or maybe higher pricing for its services.
# The larger gap between fare and distance indicates that the price per km might be high.
#
# Jaipur might need to review the pricing strategy, if the pricing strategy is not justified, it might lead tot he dissatisfaction of the customer.
#
# On the other hand, Surat has the lowest average fare(117.272925) suggesting lower demands or lower pricing.
# Cities like Surat, Vadodara, Coimbatore and Lucknow can increase their marketing campaigns for their affordable pricing to attract the customers.

# %%
avg_fare_dist_melted
# Out:
#         city_name        Metric       Value
# 0   Visakhapatnam      avg_fare  282.672284
# 1      Chandigarh      avg_fare  283.686950
# 2           Surat      avg_fare  117.272925
# 3        Vadodara      avg_fare  118.566165
# 4          Mysore      avg_fare  249.707168
# 5           Kochi      avg_fare  335.245079
# 6          Indore      avg_fare  179.838609
# 7          Jaipur      avg_fare  483.918128
# 8      Coimbatore      avg_fare  166.982183
# 9         Lucknow      avg_fare  147.180376
# 10  Visakhapatnam  avg_distance   22.553938
# 11     Chandigarh  avg_distance   23.518714
# 12          Surat  avg_distance   10.997247
# 13       Vadodara  avg_distance   11.517736
# 14         Mysore  avg_distance   16.496921
# 15          Kochi  avg_distance   24.065461
# 16         Indore  avg_distance   16.502473
# 17         Jaipur  avg_distance   30.023125
# 18     Coimbatore  avg_distance   14.979198
# 19        Lucknow  avg_distance   12.512963

# %% [markdown]
# **Average Ratings by City and Passenger Type**

# %%
#grouping the data based on average passenger and driver rating by city
avg_rating_bycity=trip_summary.groupby(['city_id','passenger_type']).agg(passenger_rating=('passenger_rating','mean'),
                                                      driver_rating=('driver_rating','mean'))

# %%
avg_rating_bycity=avg_rating_bycity.reset_index()

# %%
avg_rating_bycity
# Out:
#    city_id passenger_type  passenger_rating  driver_rating
# 0     AP01            new          8.976151       8.979995
# 1     AP01       repeated          7.989628       8.992701
# 2     CH01            new          8.489158       7.992120
# 3     CH01       repeated          7.493798       7.472824
# 4     GJ01            new          7.984173       6.994925
# 5     GJ01       repeated          5.995511       6.479441
# 6     GJ02            new          7.979263       7.004147
# 7     GJ02       repeated          5.978629       6.481072
# 8     KA01            new          8.982964       8.982878
# 9     KA01       repeated          7.978495       8.965767
# 10    KL01            new          8.987394       8.985350
# 11    KL01       repeated          8.003665       8.989830
# 12    MP01            new          8.485837       7.970800
# 13    MP01       repeated          7.473961       7.477404
# 14    RJ01            new          8.985018       8.988246
# ...

# %%
#joining the table based on 'city_id'
avg_rating_bycity=avg_rating_bycity.merge(city,on='city_id',how='left')

# %%
avg_rating_bycity.reset_index()
# Out:
#     index city_id passenger_type  avg_passenger_rating  avg_driver_rating  \
# 0       0    AP01            new              8.976151           8.979995
# 1       1    AP01       repeated              7.989628           8.992701
# 2       2    CH01            new              8.489158           7.992120
# 3       3    CH01       repeated              7.493798           7.472824
# 4       4    GJ01            new              7.984173           6.994925
# 5       5    GJ01       repeated              5.995511           6.479441
# 6       6    GJ02            new              7.979263           7.004147
# 7       7    GJ02       repeated              5.978629           6.481072
# 8       8    KA01            new              8.982964           8.982878
# 9       9    KA01       repeated              7.978495           8.965767
# 10     10    KL01            new              8.987394           8.985350
# 11     11    KL01       repeated              8.003665           8.989830
# ...

# %%
avg_rating_bycity.rename(columns={'passenger_rating':'avg_passenger_rating','driver_rating':'avg_driver_rating'},inplace=True)

# %%
avg_rating_bycity
# Out:
#    city_id passenger_type  avg_passenger_rating  avg_driver_rating  \
# 0     AP01            new              8.976151           8.979995
# 1     AP01       repeated              7.989628           8.992701
# 2     CH01            new              8.489158           7.992120
# 3     CH01       repeated              7.493798           7.472824
# 4     GJ01            new              7.984173           6.994925
# 5     GJ01       repeated              5.995511           6.479441
# 6     GJ02            new              7.979263           7.004147
# 7     GJ02       repeated              5.978629           6.481072
# 8     KA01            new              8.982964           8.982878
# 9     KA01       repeated              7.978495           8.965767
# 10    KL01            new              8.987394           8.985350
# 11    KL01       repeated              8.003665           8.989830
# 12    MP01            new              8.485837           7.970800
# ...

# %%
avg_rating_bycity_melted = avg_rating_bycity.melt(id_vars=['city_name', 'passenger_type'],
                                          value_vars=['avg_passenger_rating', 'avg_driver_rating'],
                                          var_name='Rating_Type', value_name='Average_Rating')

plt.figure(figsize=(12, 6))
sns.barplot(data=avg_rating_bycity_melted, x='city_name', y='Average_Rating', hue='Rating_Type' ,errorbar=None,palette='viridis')
plt.xlabel('City')
plt.ylabel('Average Rating')
plt.title('Comparison of Avg Passenger and Driver Rating by City')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
highest_avg_rating=avg_rating_bycity.loc[avg_rating_bycity['avg_passenger_rating'].idxmax()]
lowest_avg_rating=avg_rating_bycity.loc[avg_rating_bycity['avg_passenger_rating'].idxmin()]
print("The highest average passenger rating is:")
print(highest_avg_rating)
print('\n')
print("The lowest average passenger rating is:")
print(lowest_avg_rating)
# Out:
# The highest average passenger rating is:
# city_id                     KL01
# passenger_type               new
# avg_passenger_rating    8.987394
# avg_driver_rating        8.98535
# city_name                  Kochi
# Name: 10, dtype: object
#
#
# The lowest average passenger rating is:
# city_id                     GJ02
# passenger_type          repeated
# avg_passenger_rating    5.978629
# avg_driver_rating       6.481072
# city_name               Vadodara
# Name: 7, dtype: object

# %% [markdown]
# Kochi has the highest average passenger rating(8.987394). This suggests that  **new passengers** in Kochi are highly satisfied with the service.
# The average driver ratings are also high, suggesting that the overall experience for both passengers and drivers is very positive in Kochi.
#
# **Recommendation**: The practices that are being followed in Kochi can also be analyzed and implemented in other cities to improve ratings.
#
# Vadodara has the lowest average passenger rating among the **repeat passengers** (5.978629). This is a sign that returning passengers are not happy with the service. Also, The driver rating in Vadodara is also relatively low, indicating that drivers are also not entirely satisfied, or the interaction between the passenger and driver may be poor.
#
# In Surat and Vadodara, there is a significant difference between the ratings given by new and repeat passengers, with repeat passengers rating the service much lower.
#
# **Recommendation**: Investigate reasons for dissatisfaction among repeat passengers, and implement improvements. Focus on customer retention strategies and improving the overall experience for repeat passengers in these cities.
#
# In cities like Jaipur, Mysore, Kochi and Visakhapatnam, new passengers tend to rate the service slightly higher compared to repeat passengers.
# This trend could suggest that new passengers find the initial experience appealing, but there might be areas where the service consistency drops as customers continue using it.

# %% [markdown]
# **OVERALL RECOMMENDATIONS:**
#
# Cities like Kochi, Mysore, and Visakhapatnam have high ratings for both new and repeat passengers. You can analyze these cities to see what is working well and apply similar strategies in cities with lower ratings.
#
# Some cities show lower driver ratings. Consider providing additional training for drivers to improve their interaction with passengers and ensure better overall satisfaction.
#
# In several cities, repeat passengers give significantly lower ratings compared to new passengers, particularly in Vadodara and Surat. Consider adding incentives for repeat customers like offer discount or coupon codes for upcoming rides to loyal customers or evaluating if service consistency is being maintained.

# %%
#grouping the data based on average passenger and driver rating by passenger type
avg_rating_passengertype=trip_summary.groupby('passenger_type').agg(avg_passenger_rating=('passenger_rating','mean'),
                                                                          avg_driver_rating=('driver_rating','mean'))
avg_rating_passengertype.reset_index()
# Out:
#   passenger_type  avg_passenger_rating  avg_driver_rating
# 0            new              8.649849           8.319043
# 1       repeated              6.957892           7.483859

# %%
avg_rating_passengertype.plot(kind='bar',ylabel='avg_rating', title='Comparison of Avg Rating by Passenger Type')
# Out:
# <Axes: title={'center': 'Comparison of Avg Rating by Passenger Type'}, xlabel='passenger_type', ylabel='avg_rating'>

# %% [markdown]
# The analysis reveals that new passengers give higher average ratings (8.65) compared to repeat passengers (6.96), indicating that initial experiences are more positive. However, the decline in ratings for repeat passengers suggests a drop in satisfaction over time, likely due to inconsistent service quality. On the other hand, drivers rate repeat passengers slightly higher (7.48) than new passengers (8.32), possibly due to increased familiarity.
#
# **Improve the Experience for Repeat Passengers:**
#
# The decline in ratings from new to repeat passengers suggests that there is a gap in service consistency. Addressing this gap is critical to ensure that passengers continue to feel satisfied with the service over time.
# Consider gathering feedback from repeat passengers to understand what issues they are facing and why their satisfaction is decreasing.

# %% [markdown]
# **PEAK AND LOW DEMAND MONTHS BY CITY**

# %%
#extracting the month from the date column
trip_summary['date'] = pd.to_datetime(trip_summary['date'])
trip_summary['month'] = trip_summary['date'].dt.to_period('M')

# %%
# Grouping by city and month to calculate the total number of trips in each month for each city
trip_demand_by_city = trip_summary.groupby(['city_id', 'month']).size().reset_index(name='trip_count')

# %%
trip_demand_by_city=trip_demand_by_city.merge(city,on='city_id',how='left')

# %%
trip_demand_by_city.rename(columns={'city_name_y':'city_name'},inplace=True)

# %%
trip_demand_by_city
# Out:
#    city_id    month  trip_count      city_name
# 0     AP01  2024-01        4468  Visakhapatnam
# 1     AP01  2024-02        4793  Visakhapatnam
# 2     AP01  2024-03        4877  Visakhapatnam
# 3     AP01  2024-04        4938  Visakhapatnam
# 4     AP01  2024-05        4812  Visakhapatnam
# 5     AP01  2024-06        4478  Visakhapatnam
# 6     CH01  2024-01        6810     Chandigarh
# 7     CH01  2024-02        7387     Chandigarh
# 8     CH01  2024-03        6569     Chandigarh
# 9     CH01  2024-04        5566     Chandigarh
# 10    CH01  2024-05        6620     Chandigarh
# 11    CH01  2024-06        6029     Chandigarh
# 12    GJ01  2024-01        8358          Surat
# 13    GJ01  2024-02        9069          Surat
# 14    GJ01  2024-03        9267          Surat
# 15    GJ01  2024-04        9831          Surat
# 16    GJ01  2024-05        9774          Surat
# 17    GJ01  2024-06        8544          Surat
# 18    GJ02  2024-01        4775       Vadodara
# ...

# %%
peak_demand = trip_demand_by_city.loc[trip_demand_by_city.groupby('city_id')['trip_count'].idxmax()].reset_index(drop=True)

# %%
print("Months with the highest demand")
peak_demand
# Out:
# Months with the highest demand
#   city_id    month  trip_count      city_name
# 0    AP01  2024-04        4938  Visakhapatnam
# 1    CH01  2024-02        7387     Chandigarh
# 2    GJ01  2024-04        9831          Surat
# 3    GJ02  2024-04        5941       Vadodara
# 4    KA01  2024-05        3007         Mysore
# 5    KL01  2024-05       10014          Kochi
# 6    MP01  2024-05        7787         Indore
# 7    RJ01  2024-02       15872         Jaipur
# 8    TN01  2024-03        3680     Coimbatore
# 9    UP01  2024-02       12060        Lucknow

# %%
low_demand = trip_demand_by_city.loc[trip_demand_by_city.groupby('city_id')['trip_count'].idxmin()].reset_index(drop=True)

# %%
print("Months with the lowest demand")
low_demand
# Out:
# Months with the lowest demand
#   city_id    month  trip_count      city_name
# 0    AP01  2024-01        4468  Visakhapatnam
# 1    CH01  2024-04        5566     Chandigarh
# 2    GJ01  2024-01        8358          Surat
# 3    GJ02  2024-06        4685       Vadodara
# 4    KA01  2024-01        2485         Mysore
# 5    KL01  2024-06        6399          Kochi
# 6    MP01  2024-06        6288         Indore
# 7    RJ01  2024-06        9842         Jaipur
# 8    TN01  2024-06        3158     Coimbatore
# 9    UP01  2024-05        9705        Lucknow

# %%
peak_demand.rename(columns={'month': 'peak_month', 'trip_count': 'peak_trip_count'}, inplace=True)
low_demand.rename(columns={'month': 'low_month', 'trip_count': 'low_trip_count'}, inplace=True)

# %%
# Merging the peak and low demand DataFrames to get a complete demand analysis for each city
demand_analysis = peak_demand.merge(low_demand, on='city_id', how='left')
demand_analysis.drop(columns=['city_name_x'],inplace=True)
demand_analysis.rename(columns={'city_name_y':'city_name'},inplace=True)
display(demand_analysis)
# Out:
#   city_id peak_month  peak_trip_count low_month  low_trip_count      city_name
# 0    AP01    2024-04             4938   2024-01            4468  Visakhapatnam
# 1    CH01    2024-02             7387   2024-04            5566     Chandigarh
# 2    GJ01    2024-04             9831   2024-01            8358          Surat
# 3    GJ02    2024-04             5941   2024-06            4685       Vadodara
# 4    KA01    2024-05             3007   2024-01            2485         Mysore
# 5    KL01    2024-05            10014   2024-06            6399          Kochi
# 6    MP01    2024-05             7787   2024-06            6288         Indore
# 7    RJ01    2024-02            15872   2024-06            9842         Jaipur
# 8    TN01    2024-03             3680   2024-06            3158     Coimbatore
# 9    UP01    2024-02            12060   2024-05            9705        Lucknow

# %% [markdown]
# The above analysis shows that cities like Jaipur and Lucknow have their highest demand in February, whereas cities like Visakhapatnam, Surat, Vadodara, and Mysore have their peak time in April or May.
#
# Chandigarh and Coimbatore show earlier peak months like February and March, respectively, while Kochi and Indore have highest passenegers in May.
#
# Jaipur has the highest peak demand with 15,872 trips in February.
#
# Kochi also shows a high peak demand of 10,014 trips in May.
#
# The peak month for Lucknow is February with 12,060 trips.
#
# This indicates that the particular month may be related to some festival, special event or maybe some tourism, seasonal factors like vacations that could spike up the demand in the cab service in those particular cities.
#
# In contrast to this, Mysore and Surat have their lowest demand in January.
#
# Kochi, Indore, Vadodara, Jaipur, and Coimbatore all show low demand in June, suggesting that summer months might see a show a decline in demand, which may be due to weather conditions.
#
# For Visakhapatnam, the lowest demand month is January, which may imply that the beginning of the year is generally a quieter period for travel.

# %% [markdown]
# **RECOMMENDATIONS**
#
# To optimize operations, Goodcabs should allocate additional resources (drivers and vehicles) to cities like Jaipur, Kochi, and Lucknow during their peak months to meet the high demand.
#
# During low-demand months (such as June in Jaipur, Kochi, and Indore), promotional campaigns and special offers can be used to encourage usage.
#
#  Seasonal patterns like peak demand in April, May, and February suggest focusing on favorable weather or holidays, During the low demand in June, providing comfort services, like air-conditioned premium rides, could help boost demand in hot months.

# %% [markdown]
# **WEEKEND VS WEEKDAY TRIP DEMAND BY CITY**

# %%
dim_date_df['date']=pd.to_datetime(dim_date_df['date'])

# %%
trip_details['date']=pd.to_datetime(trip_details['date'])

# %%
#merge the trip_details df with dim_date_df to get the day_type column
daytype_analysis= trip_details.merge(dim_date_df,on='date',how='right')
daytype_analysis
# Out:
#                      trip_id       date city_id passenger_type  \
# 0       TRPVAD24010181cc6f06 2024-01-01    GJ02       repeated
# 1       TRPJAI24010135dfc403 2024-01-01    RJ01       repeated
# 2       TRPLUC240101f6ddc0ac 2024-01-01    UP01       repeated
# 3       TRPLUC24010116eb8979 2024-01-01    UP01       repeated
# 4       TRPCOI2401011159a37f 2024-01-01    TN01       repeated
# ...                      ...        ...     ...            ...
# 425898  TRPSUR24063046ef40df 2024-06-30    GJ01       repeated
# 425899  TRPJAI2406303919cf7b 2024-06-30    RJ01            new
# 425900  TRPCHA24063076c8558a 2024-06-30    CH01            new
# 425901  TRPJAI24063008c1ff82 2024-06-30    RJ01       repeated
# 425902  TRPJAI2406308d9b305b 2024-06-30    RJ01       repeated
#
#         distance_travelled(km)  fare_amount  passenger_rating  driver_rating  \
# 0                            8           82                 5              7
# ...

# %%
#grouping the data based on city name and daytype column to get the total trips
trip_count=daytype_analysis.groupby(['city_name','day_type']).size().reset_index(name='Trip_count')

# %%
trip_count.reset_index()
# Out:
#     index      city_name day_type  Trip_count
# 0       0     Chandigarh  Weekday       19914
# 1       1     Chandigarh  Weekend       19067
# 2       2     Coimbatore  Weekday       12576
# 3       3     Coimbatore  Weekend        8528
# 4       4         Indore  Weekday       21198
# 5       5         Indore  Weekend       21258
# 6       6         Jaipur  Weekday       32491
# 7       7         Jaipur  Weekend       44397
# 8       8          Kochi  Weekday       22915
# 9       9          Kochi  Weekend       27787
# 10     10        Lucknow  Weekday       49617
# 11     11        Lucknow  Weekend       14682
# 12     12         Mysore  Weekday        6424
# 13     13         Mysore  Weekend        9814
# 14     14          Surat  Weekday       37793
# 15     15          Surat  Weekend       17050
# 16     16       Vadodara  Weekday       20310
# 17     17       Vadodara  Weekend       11716
# 18     18  Visakhapatnam  Weekday       15100
# ...

# %%
# Pivoting the data for easier comparison between Weekday and Weekend trip counts
trip_counts_pivot = trip_count.pivot(index='city_name', columns='day_type', values='Trip_count').fillna(0)

# %%
trip_counts_pivot
# Out:
# day_type       Weekday  Weekend
# city_name
# Chandigarh       19914    19067
# Coimbatore       12576     8528
# Indore           21198    21258
# Jaipur           32491    44397
# Kochi            22915    27787
# Lucknow          49617    14682
# Mysore            6424     9814
# Surat            37793    17050
# Vadodara         20310    11716
# Visakhapatnam    15100    13266

# %%
trip_counts_pivot.plot(kind='bar',figsize=(12, 6))
plt.xlabel('City Name')
plt.ylabel('Number of Trips')
plt.title('Comparison of Weekday and Weekend Trip Counts by City')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# The analysis shows that **Lucknow** has the highest preference for **weekday trips** with **49,617** trips on weekdays versus **14,682** on weekends. **Surat** also exhibits a strong **weekday preference** with **37,793** weekday trips compared to **17,050** weekend trips. Conversely, **Jaipur** has a significant **weekend preference** with **44,397** trips on weekends compared to **32,491** on weekdays.

# %% [markdown]
# **Repeat Passeneger Frequency and City Contribution Analysis**

# %%
repeat_trip_details=repeat_trip.merge(city,on='city_id',how='right')
display(repeat_trip_details)
# Out:
#           month city_id trip_count  repeat_passenger_count city_name
# 0    2024-01-01    RJ01   10-Trips                      13    Jaipur
# 1    2024-01-01    RJ01    2-Trips                     705    Jaipur
# 2    2024-01-01    RJ01    3-Trips                     278    Jaipur
# 3    2024-01-01    RJ01    4-Trips                     194    Jaipur
# 4    2024-01-01    RJ01    5-Trips                     118    Jaipur
# ..          ...     ...        ...                     ...       ...
# 535  2024-06-01    KA01    5-Trips                      16    Mysore
# 536  2024-06-01    KA01    6-Trips                       7    Mysore
# 537  2024-06-01    KA01    7-Trips                       5    Mysore
# 538  2024-06-01    KA01    8-Trips                       5    Mysore
# 539  2024-06-01    KA01    9-Trips                       1    Mysore
#
# [540 rows x 5 columns]

# %%
# Grouping by city_name to calculate the total number of repeat passengers in each city
total_repeat_passengers = repeat_trip_details.groupby('city_name')['repeat_passenger_count'].sum().reset_index()
total_repeat_passengers.rename(columns={'repeat_passenger_count': 'total_repeat_passenger_count'}, inplace=True)
total_repeat_passengers
# Out:
#        city_name  total_repeat_passenger_count
# 0     Chandigarh                          5070
# 1     Coimbatore                          2551
# 2         Indore                          7216
# 3         Jaipur                          9682
# 4          Kochi                          7626
# 5        Lucknow                          9597
# 6         Mysore                          1477
# 7          Surat                          8638
# 8       Vadodara                          4346
# 9  Visakhapatnam                          5108

# %%
repeat_trip_with_total=repeat_trip_details.merge(total_repeat_passengers,on='city_name',how='left')
repeat_trip_with_total
# Out:
#           month city_id trip_count  repeat_passenger_count city_name  \
# 0    2024-01-01    RJ01   10-Trips                      13    Jaipur
# 1    2024-01-01    RJ01    2-Trips                     705    Jaipur
# 2    2024-01-01    RJ01    3-Trips                     278    Jaipur
# 3    2024-01-01    RJ01    4-Trips                     194    Jaipur
# 4    2024-01-01    RJ01    5-Trips                     118    Jaipur
# ..          ...     ...        ...                     ...       ...
# 535  2024-06-01    KA01    5-Trips                      16    Mysore
# 536  2024-06-01    KA01    6-Trips                       7    Mysore
# 537  2024-06-01    KA01    7-Trips                       5    Mysore
# 538  2024-06-01    KA01    8-Trips                       5    Mysore
# 539  2024-06-01    KA01    9-Trips                       1    Mysore
#
#      total_repeat_passenger_count
# 0                            9682
# 1                            9682
# ...

# %%
#calculating the percentage
repeat_trip_with_total['percentage_of_passengers'] = (
    repeat_trip_with_total['repeat_passenger_count'] / repeat_trip_with_total['total_repeat_passenger_count'] * 100
)

# %%
repeat_trip_with_total
# Out:
#           month city_id trip_count  repeat_passenger_count city_name  \
# 0    2024-01-01    RJ01   10-Trips                      13    Jaipur
# 1    2024-01-01    RJ01    2-Trips                     705    Jaipur
# 2    2024-01-01    RJ01    3-Trips                     278    Jaipur
# 3    2024-01-01    RJ01    4-Trips                     194    Jaipur
# 4    2024-01-01    RJ01    5-Trips                     118    Jaipur
# ..          ...     ...        ...                     ...       ...
# 535  2024-06-01    KA01    5-Trips                      16    Mysore
# 536  2024-06-01    KA01    6-Trips                       7    Mysore
# 537  2024-06-01    KA01    7-Trips                       5    Mysore
# 538  2024-06-01    KA01    8-Trips                       5    Mysore
# 539  2024-06-01    KA01    9-Trips                       1    Mysore
#
#      total_repeat_passenger_count  percentage_of_passengers
# 0                            9682                  0.134270
# ...

# %%
#removing the -trips from the trip_count column
repeat_trip_with_total['trip_count'] = repeat_trip_with_total['trip_count'].str.replace('-Trips', '').astype(int)

# %%
repeat_trip_with_total
# Out:
#           month city_id  trip_count  repeat_passenger_count city_name  \
# 0    2024-01-01    RJ01          10                      13    Jaipur
# 1    2024-01-01    RJ01           2                     705    Jaipur
# 2    2024-01-01    RJ01           3                     278    Jaipur
# 3    2024-01-01    RJ01           4                     194    Jaipur
# 4    2024-01-01    RJ01           5                     118    Jaipur
# ..          ...     ...         ...                     ...       ...
# 535  2024-06-01    KA01           5                      16    Mysore
# 536  2024-06-01    KA01           6                       7    Mysore
# 537  2024-06-01    KA01           7                       5    Mysore
# 538  2024-06-01    KA01           8                       5    Mysore
# 539  2024-06-01    KA01           9                       1    Mysore
#
#      total_repeat_passenger_count  percentage_of_passengers
# 0                            9682                  0.134270
# ...

# %%
# multiplying trip_count with repeat_passenger_count to get the total number of trip
repeat_trip_with_total['total_trips_for_each_record'] = repeat_trip_with_total['trip_count'] * repeat_trip_with_total['repeat_passenger_count']

# grouping by city_name to calculate the total trip count for each city
total_trip_count = repeat_trip_with_total.groupby('city_name')['total_trips_for_each_record'].sum().reset_index()
total_trip_count.rename(columns={'total_trips_for_each_record': 'total_trip_count'}, inplace=True)
display(total_trip_count)
# Out:
#        city_name  total_trip_count
# 0     Chandigarh             20073
# 1     Coimbatore             12590
# 2         Indore             27593
# 3         Jaipur             31032
# 4          Kochi             24286
# 5        Lucknow             48039
# 6         Mysore              4557
# 7          Surat             43217
# 8       Vadodara             21899
# 9  Visakhapatnam             15619

# %%
highest_trip_count=total_trip_count.loc[total_trip_count['total_trip_count'].idxmax()]
print("The highest trip count is:")
highest_trip_count
# Out:
# The highest trip count is:
# city_name           Lucknow
# total_trip_count      48039
# Name: 5, dtype: object

# %%
lowest_trip_count=total_trip_count.loc[total_trip_count['total_trip_count'].idxmin()]
print("The highest trip count is:")
lowest_trip_count
# Out:
# The highest trip count is:
# city_name           Mysore
# total_trip_count      4557
# Name: 6, dtype: object

# %% [markdown]
# The analysis shows Lucknow with the highest total trip count of 48,039, indicating high engagement from repeat passengers. Surat also shows a high total trip count of 43,217, reflecting strong demand. Interestingly, Jaipur has 31,032 trips but also has a relatively high repeat passenger count of 9,682, suggesting a good repeat usage pattern.
#
# For cities with high repeat passenger counts, like Jaipur and Lucknow, continue to enhance the loyalty programs and provide special perks to retain these users.
#
# Lucknow, Surat, and Jaipur have shown high trip counts, with significant repeat passenger engagement. Goodcabs should consider increasing the number of available cabs and drivers in these cities to meet demand more effectively.
#
# Mysore and Visakhapatnam have lower total trip counts compared to other cities. Introducing targeted promotional campaigns and discounts could help boost demand in these cities.
#
# Cities like Chandigarh, Indore, and Kochi, which show moderate repeat engagement, could benefit from more convenient ride options for business users, such as corporate packages or priority booking for busy hours.
#
# Increase fleet size in cities like Lucknow, Jaipur, and Surat to handle peak demand and avoid potential service disruptions.

# %% [markdown]
# **Monthly Target Achievement Analysis for Key Metrics**

# %%
#average passenger rating v/s target average passenger rating
print("The average passenger rating for each city")
avg_passenger_rating=avg_rating_bycity.drop(columns=['avg_driver_rating'])
avg_passenger_rating
# Out:
# The average passenger rating for each city
#    city_id passenger_type  avg_passenger_rating      city_name
# 0     AP01            new              8.976151  Visakhapatnam
# 1     AP01       repeated              7.989628  Visakhapatnam
# 2     CH01            new              8.489158     Chandigarh
# 3     CH01       repeated              7.493798     Chandigarh
# 4     GJ01            new              7.984173          Surat
# 5     GJ01       repeated              5.995511          Surat
# 6     GJ02            new              7.979263       Vadodara
# 7     GJ02       repeated              5.978629       Vadodara
# 8     KA01            new              8.982964         Mysore
# 9     KA01       repeated              7.978495         Mysore
# 10    KL01            new              8.987394          Kochi
# 11    KL01       repeated              8.003665          Kochi
# 12    MP01            new              8.485837         Indore
# ...

# %%
#grouping the data based on city name and average passenger rating
compare_avg_rating=avg_passenger_rating.groupby(['city_id','city_name'])['avg_passenger_rating'].mean().reset_index()
compare_avg_rating
# Out:
#   city_id      city_name  avg_passenger_rating
# 0    AP01  Visakhapatnam              8.482890
# 1    CH01     Chandigarh              7.991478
# 2    GJ01          Surat              6.989842
# 3    GJ02       Vadodara              6.978946
# 4    KA01         Mysore              8.480729
# 5    KL01          Kochi              8.495529
# 6    MP01         Indore              7.979899
# 7    RJ01         Jaipur              8.488030
# 8    TN01     Coimbatore              7.980622
# 9    UP01        Lucknow              6.981585

# %%
#lets compare it with the target average passenger rating
target_avg_passenger_rating=target_rating.merge(city,on='city_id',how='right')
target_avg_passenger_rating
# Out:
#   city_id  target_avg_passenger_rating      city_name
# 0    RJ01                         8.25         Jaipur
# 1    UP01                         7.25        Lucknow
# 2    GJ01                         7.00          Surat
# 3    KL01                         8.50          Kochi
# 4    MP01                         8.00         Indore
# 5    CH01                         8.00     Chandigarh
# 6    GJ02                         7.50       Vadodara
# 7    AP01                         8.50  Visakhapatnam
# 8    TN01                         8.25     Coimbatore
# 9    KA01                         8.50         Mysore

# %%
#comparison between the achieved average passenger rating and target average passenger rating
#merging the two df
compare_avg_passenger_rating=compare_avg_rating.merge(target_avg_passenger_rating,on='city_id',how='left')
compare_avg_passenger_rating
# Out:
#   city_id    city_name_x  avg_passenger_rating  target_avg_passenger_rating  \
# 0    AP01  Visakhapatnam              8.482890                         8.50
# 1    CH01     Chandigarh              7.991478                         8.00
# 2    GJ01          Surat              6.989842                         7.00
# 3    GJ02       Vadodara              6.978946                         7.50
# 4    KA01         Mysore              8.480729                         8.50
# 5    KL01          Kochi              8.495529                         8.50
# 6    MP01         Indore              7.979899                         8.00
# 7    RJ01         Jaipur              8.488030                         8.25
# 8    TN01     Coimbatore              7.980622                         8.25
# 9    UP01        Lucknow              6.981585                         7.25
#
#      city_name_y
# 0  Visakhapatnam
# 1     Chandigarh
# 2          Surat
# 3       Vadodara
# 4         Mysore
# 5          Kochi
# ...

# %%
compare_avg_passenger_rating.drop(columns=['city_name_x'],inplace=True)
compare_avg_passenger_rating.rename(columns={'city_name_y':'city_name'},inplace=True)

# %%
compare_avg_passenger_rating
# Out:
#   city_id  avg_passenger_rating  target_avg_passenger_rating      city_name
# 0    AP01              8.482890                         8.50  Visakhapatnam
# 1    CH01              7.991478                         8.00     Chandigarh
# 2    GJ01              6.989842                         7.00          Surat
# 3    GJ02              6.978946                         7.50       Vadodara
# 4    KA01              8.480729                         8.50         Mysore
# 5    KL01              8.495529                         8.50          Kochi
# 6    MP01              7.979899                         8.00         Indore
# 7    RJ01              8.488030                         8.25         Jaipur
# 8    TN01              7.980622                         8.25     Coimbatore
# 9    UP01              6.981585                         7.25        Lucknow

# %%
compare_avg_passenger_rating_melted = compare_avg_passenger_rating.melt(id_vars='city_name',
                                          value_vars=['avg_passenger_rating', 'target_avg_passenger_rating'],
                                          var_name='Metric', value_name='Avg_passenger_rating')

plt.figure(figsize=(12, 6))
sns.barplot(data=compare_avg_passenger_rating_melted, x='city_name', y='Avg_passenger_rating', hue='Metric')
plt.xlabel('City')
plt.ylabel('Avg_passenger_rating')
plt.title('Comparison of Avg Passenger Rating and Target Avg Passenger Rating')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# The analysis shows that Visakhapatnam, Mysore, and Kochi have met or slightly exceeded their target average passenger ratings of 8.50, with ratings of 8.48, 8.48, and 8.49, respectively. This suggests strong customer satisfaction in these cities. Chandigarh has also achieved close to its target of 8.00, with an actual rating of 7.99. However, Surat, Vadodara, and Lucknow have not met their target ratings, with scores of 6.98, 6.97, and 6.98 compared to targets of 7.00, 7.50, and 7.25, respectively. These cities may be struggling with passenger satisfaction.
#
# **RECOMMENDATIONS:**
#
#  Focus on improving service quality in Surat, Vadodara, and Lucknow through initiatives like driver training programs and service improvements to increase the passenger satisfaction.
#
#  Consider options for rewarding the drivers in cities like Visakhapatnam, Mysore, and Kochi where ratings have met targets, to continue maintaining high standards and further boost ratings.
#
#  Another recommendation could be to collect feedback from passengers in the lower-performing cities to identify specific issues impacting ratings, such as driver behavior, cab cleanliness, or ride comfort. Addressing these issues can bridge the gap between actual and target ratings.

# %%
#comparison between achieved new passenger and target new passengers
print("The achieved number of new passengers by Goodcabs")
passenger
# Out:
# The achieved number of new passengers by Goodcabs
#          month city_id  new_passengers  repeat_passengers  total_passengers
# 0   2024-01-01    AP01            2513                650              3163
# 1   2024-01-01    CH01            3920                720              4640
# 2   2024-01-01    GJ01            2432               1184              3616
# 3   2024-01-01    GJ02            2089                544              2633
# 4   2024-01-01    KA01            1957                172              2129
# 5   2024-01-01    KL01            4865                795              5660
# 6   2024-01-01    MP01            2843               1033              3876
# 7   2024-01-01    RJ01           10423               1422             11845
# 8   2024-01-01    TN01            1822                392              2214
# 9   2024-01-01    UP01            3465               1431              4896
# 10  2024-02-01    AP01            2380                790              3170
# ...

# %%
print("The targeted number of new passengers by Goodcabs")
display(target_passengers)
# Out:
# The targeted number of new passengers by Goodcabs
#          month city_id  target_new_passengers
# 0   2024-05-01    GJ01                   1500
# 1   2024-05-01    GJ02                   1500
# 2   2024-03-01    GJ01                   2000
# 3   2024-05-01    UP01                   2000
# 4   2024-05-01    MP01                   2000
# 5   2024-01-01    AP01                   2500
# 6   2024-03-01    MP01                   2700
# 7   2024-06-01    CH01                   3000
# 8   2024-04-01    AP01                   2000
# 9   2024-01-01    KA01                   2000
# 10  2024-03-01    UP01                   3200
# 11  2024-02-01    AP01                   2500
# 12  2024-04-01    GJ02                   1500
# 13  2024-02-01    TN01                   1500
# 14  2024-01-01    MP01                   2700
# 15  2024-03-01    TN01                   1500
# 16  2024-05-01    KA01                   2000
# 17  2024-05-01    TN01                   1000
# ...

# %%
#grouping the df based on city id to check the total number of new passengers for each city
achieved_new_passengers=passenger.groupby('city_id')['new_passengers'].sum().reset_index()
achieved_new_passengers
# Out:
#   city_id  new_passengers
# 0    AP01           12747
# 1    CH01           18908
# 2    GJ01           11626
# 3    GJ02           10127
# 4    KA01           11681
# 5    KL01           26416
# 6    MP01           14863
# 7    RJ01           45856
# 8    TN01            8514
# 9    UP01           16260

# %%
#similarly grouping the target passengers in each city
targeted_new_passengers=target_passengers.groupby('city_id')['target_new_passengers'].sum().reset_index()
targeted_new_passengers
# Out:
#   city_id  target_new_passengers
# 0    AP01                  13500
# 1    CH01                  21000
# 2    GJ01                  10500
# 3    GJ02                   9900
# 4    KA01                  12000
# 5    KL01                  27000
# 6    MP01                  14100
# 7    RJ01                  54000
# 8    TN01                   7500
# 9    UP01                  15600

# %%
compare_new_passengers=achieved_new_passengers.merge(targeted_new_passengers,on='city_id',how='left')
compare_new_passengers
# Out:
#   city_id  new_passengers  target_new_passengers
# 0    AP01           12747                  13500
# 1    CH01           18908                  21000
# 2    GJ01           11626                  10500
# 3    GJ02           10127                   9900
# 4    KA01           11681                  12000
# 5    KL01           26416                  27000
# 6    MP01           14863                  14100
# 7    RJ01           45856                  54000
# 8    TN01            8514                   7500
# 9    UP01           16260                  15600

# %%
compare_new_passengers.rename(columns={'new_passengers':'achieved_new_passengers'},inplace=True)

# %%
compare_new_passenger=compare_new_passengers.merge(city,on='city_id',how='left')
compare_new_passenger
# Out:
#   city_id  achieved_new_passengers  target_new_passengers      city_name
# 0    AP01                    12747                  13500  Visakhapatnam
# 1    CH01                    18908                  21000     Chandigarh
# 2    GJ01                    11626                  10500          Surat
# 3    GJ02                    10127                   9900       Vadodara
# 4    KA01                    11681                  12000         Mysore
# 5    KL01                    26416                  27000          Kochi
# 6    MP01                    14863                  14100         Indore
# 7    RJ01                    45856                  54000         Jaipur
# 8    TN01                     8514                   7500     Coimbatore
# 9    UP01                    16260                  15600        Lucknow

# %%
compare_new_passenger_melted=compare_new_passenger.melt(id_vars='city_name',
                                                        value_vars=['achieved_new_passengers','target_new_passengers'],
                                                        var_name='Passengers',value_name='Value')
plt.figure(figsize=(12, 6))
sns.barplot(data=compare_new_passenger_melted,x='city_name',y='Value',hue='Passengers')
plt.title('Achieved new passengers V/S Targeted new passengers')
plt.xlabel('City Name')
plt.ylabel('New Passengers')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The analysis shows that Jaipur had the highest target of 54,000 new passengers but only achieved 45,856, falling significantly short of its target. Chandigarh also fell short of its target of 21,000, achieving 18,908 new passengers. However, Surat, Vadodara, Indore, and Coimbatore exceeded their targets, with Surat achieving 11,626 against a target of 10,500 and Indore achieving 14,863 against a target of 14,100. Kochi and Visakhapatnam achieved close to their targets, but still fell slightly short.
#
# **RECOMMENDATIONS**
#
# In cities like Jaipur and Chandigarh where targets were not met, Goodcabs should focus on increasing brand awareness and special promotions to attract more new passengers.
#
# Consider reviewing the targets in Jaipur and Chandigarh to ensure they are achievable, or provide additional support to reach those high targets effectively.
#
# In cities like Surat, Vadodara, and Indore, which exceeded their targets, Goodcabs should continue the strategies that worked well.

# %%
#comparing the achieved total trips and targeted total trips by Goodcabs

# %%
print('the targeted total trips')
target_trips
# Out:
# the targeted total trips
#          month city_id  total_target_trips
# 0   2024-03-01    MP01                7000
# 1   2024-05-01    KA01                2500
# 2   2024-04-01    UP01               11000
# 3   2024-02-01    GJ02                6000
# 4   2024-05-01    KL01                9000
# 5   2024-02-01    UP01               13000
# 6   2024-01-01    AP01                4500
# 7   2024-01-01    CH01                7000
# 8   2024-02-01    KL01                7500
# 9   2024-03-01    UP01               13000
# 10  2024-02-01    TN01                3500
# 11  2024-06-01    KL01                9000
# 12  2024-04-01    KL01                9000
# 13  2024-04-01    KA01                2500
# 14  2024-06-01    GJ01               10000
# 15  2024-01-01    RJ01               13000
# 16  2024-05-01    CH01                6000
# 17  2024-03-01    KL01                7500
# 18  2024-04-01    MP01                7500
# 19  2024-05-01    RJ01                9500
# ...

# %%
#grouping the targeted total trips by city id
target_total_trip=target_trips.groupby('city_id')['total_target_trips'].sum().reset_index()
target_total_trip
# Out:
#   city_id  total_target_trips
# 0    AP01               28500
# 1    CH01               39000
# 2    GJ01               57000
# 3    GJ02               37500
# 4    KA01               13500
# 5    KL01               49500
# 6    MP01               43500
# 7    RJ01               67500
# 8    TN01               21000
# 9    UP01               72000

# %%
target_total_trip=target_total_trip.merge(city,on='city_id',how='left')

# %%
target_total_trip
# Out:
#   city_id  total_target_trips      city_name
# 0    AP01               28500  Visakhapatnam
# 1    CH01               39000     Chandigarh
# 2    GJ01               57000          Surat
# 3    GJ02               37500       Vadodara
# 4    KA01               13500         Mysore
# 5    KL01               49500          Kochi
# 6    MP01               43500         Indore
# 7    RJ01               67500         Jaipur
# 8    TN01               21000     Coimbatore
# 9    UP01               72000        Lucknow

# %%
print("The achieved total trip")
total_trip_count
# Out:
# The achieved total trip
#        city_name  total_trip_count
# 0     Chandigarh             20073
# 1     Coimbatore             12590
# 2         Indore             27593
# 3         Jaipur             31032
# 4          Kochi             24286
# 5        Lucknow             48039
# 6         Mysore              4557
# 7          Surat             43217
# 8       Vadodara             21899
# 9  Visakhapatnam             15619

# %%
achieved_vs_target_trips=total_trip_count.merge(target_total_trip,on='city_name',how='left')
# Out:
#        city_name  total_trip_count city_id  total_target_trips
# 0     Chandigarh             20073    CH01               39000
# 1     Coimbatore             12590    TN01               21000
# 2         Indore             27593    MP01               43500
# 3         Jaipur             31032    RJ01               67500
# 4          Kochi             24286    KL01               49500
# 5        Lucknow             48039    UP01               72000
# 6         Mysore              4557    KA01               13500
# 7          Surat             43217    GJ01               57000
# 8       Vadodara             21899    GJ02               37500
# 9  Visakhapatnam             15619    AP01               28500

# %%
achieved_vs_target_trips.rename(columns={'total_trip_count':'achieved_trip_count','total_target_trips':'target_trip_count'},inplace=True)

# %%
achieved_vs_target_trips
# Out:
#        city_name  achieved_trip_count city_id  target_trip_count
# 0     Chandigarh                20073    CH01              39000
# 1     Coimbatore                12590    TN01              21000
# 2         Indore                27593    MP01              43500
# 3         Jaipur                31032    RJ01              67500
# 4          Kochi                24286    KL01              49500
# 5        Lucknow                48039    UP01              72000
# 6         Mysore                 4557    KA01              13500
# 7          Surat                43217    GJ01              57000
# 8       Vadodara                21899    GJ02              37500
# 9  Visakhapatnam                15619    AP01              28500

# %%
#comapring the achieved total trips with the targeted total trip
achieved_vs_target_trips_melted=achieved_vs_target_trips.melt(id_vars='city_name',
                                                              value_vars=['achieved_trip_count','target_trip_count'],
                                                              var_name='trip_count',value_name='value')


plt.figure(figsize=(12,6))
sns.barplot(data=achieved_vs_target_trips_melted,x='city_name',y='value',hue='trip_count')
plt.xticks(rotation=45)
plt.title('Achieved new passengers V/S Targeted new passengers')
plt.xlabel('City Name')
plt.ylabel('Trip Count')
plt.show()

# %%
# Calculate difference and achievement status for total trips
achieved_vs_target_trips['difference'] = achieved_vs_target_trips['achieved_trip_count'] - achieved_vs_target_trips['target_trip_count']
achieved_vs_target_trips['status'] = achieved_vs_target_trips['difference'].apply(lambda x: 'Exceeded' if x > 0 else ('Met' if x == 0 else 'Missed'))
achieved_vs_target_trips['percentage_difference'] = (
    (achieved_vs_target_trips['achieved_trip_count'] - achieved_vs_target_trips['target_trip_count']) / achieved_vs_target_trips['target_trip_count']
) * 100

achieved_vs_target_trips
# Out:
#        city_name  achieved_trip_count city_id  target_trip_count  difference  \
# 0     Chandigarh                20073    CH01              39000      -18927
# 1     Coimbatore                12590    TN01              21000       -8410
# 2         Indore                27593    MP01              43500      -15907
# 3         Jaipur                31032    RJ01              67500      -36468
# 4          Kochi                24286    KL01              49500      -25214
# 5        Lucknow                48039    UP01              72000      -23961
# 6         Mysore                 4557    KA01              13500       -8943
# 7          Surat                43217    GJ01              57000      -13783
# 8       Vadodara                21899    GJ02              37500      -15601
# 9  Visakhapatnam                15619    AP01              28500      -12881
#
#    status  percentage_difference
# 0  Missed             -48.530769
# 1  Missed             -40.047619
# ...

# %% [markdown]
# The analysis shows that all cities have fallen short of their targeted trip counts. Lucknow, with a target of 72,000, achieved 48,039 trips, falling short by a substantial 33%. Jaipur also had a high target of 67,500 but achieved only 31,032 trips. Surat and Indore had relatively smaller targets but still could not meet their expectations, achieving 43,217 and 27,593 trips, respectively. The smaller cities like Mysore and Visakhapatnam also fell below their targets, with Mysore achieving just 4,557 trips against a target of 13,500.
#
# **RECOMMENDATIONS:**
#
# The gap between achieved and targeted trips suggests that the targets set may be overly ambitious. Goodcabs should reassess the targets and consider factors such as city demographics and current demand trends to ensure more realistic goals.
#
# Mysore has significantly lower trip counts compared to their targets. Implementing localized campaigns with special discounts or event-based promotions could help attract more customers.
#
# For cities like Lucknow and Jaipur, focus on improving service quality and customer satisfaction, as these are larger cities with high potential. Driver training and incentives to improve service might encourage higher trip counts.
#
# To help meet these targets, Goodcabs should plan peak season campaigns and promotional offers to increase demand during non-peak times.

# %% [markdown]
# **Highest and Lowest Repeat Passenger Rates by City and Month**

# %%
passenger['RPR%']=(passenger['repeat_passengers']/passenger['total_passengers'])*100

# %%
passenger
# Out:
#          month city_id  new_passengers  repeat_passengers  total_passengers  \
# 0   2024-01-01    AP01            2513                650              3163
# 1   2024-01-01    CH01            3920                720              4640
# 2   2024-01-01    GJ01            2432               1184              3616
# 3   2024-01-01    GJ02            2089                544              2633
# 4   2024-01-01    KA01            1957                172              2129
# 5   2024-01-01    KL01            4865                795              5660
# 6   2024-01-01    MP01            2843               1033              3876
# 7   2024-01-01    RJ01           10423               1422             11845
# 8   2024-01-01    TN01            1822                392              2214
# 9   2024-01-01    UP01            3465               1431              4896
# 10  2024-02-01    AP01            2380                790              3170
# ...

# %%
passenger_RPR=passenger.drop(columns=['new_passengers','repeat_passengers','total_passengers'])
passenger_RPR
# Out:
#          month city_id       RPR%
# 0   2024-01-01    AP01  20.550111
# 1   2024-01-01    CH01  15.517241
# 2   2024-01-01    GJ01  32.743363
# 3   2024-01-01    GJ02  20.660843
# 4   2024-01-01    KA01   8.078910
# 5   2024-01-01    KL01  14.045936
# 6   2024-01-01    MP01  26.651187
# 7   2024-01-01    RJ01  12.005065
# 8   2024-01-01    TN01  17.705510
# 9   2024-01-01    UP01  29.227941
# 10  2024-02-01    AP01  24.921136
# 11  2024-02-01    CH01  17.207989
# 12  2024-02-01    GJ01  36.809644
# 13  2024-02-01    GJ02  22.133527
# 14  2024-02-01    KA01   7.991266
# 15  2024-02-01    KL01  18.708116
# 16  2024-02-01    MP01  27.706606
# 17  2024-02-01    RJ01  13.341365
# 18  2024-02-01    TN01  17.360763
# 19  2024-02-01    UP01  31.977641
# 20  2024-03-01    AP01  29.841578
# 21  2024-03-01    CH01  21.268293
# 22  2024-03-01    GJ01  43.430233
# 23  2024-03-01    GJ02  30.095163
# 24  2024-03-01    KA01   9.480401
# 25  2024-03-01    KL01  21.696443
# ...

# %%
passenger_RPR_by_city=passenger_RPR.groupby('city_id')['RPR%'].mean().reset_index()
passenger_RPR_by_city
# Out:
#   city_id       RPR%
# 0    AP01  28.811272
# 1    CH01  21.750782
# 2    GJ01  42.963123
# 3    GJ02  30.793795
# 4    KA01  11.208195
# 5    KL01  22.376614
# 6    MP01  32.957829
# 7    RJ01  18.329207
# 8    TN01  23.671272
# 9    UP01  38.131873

# %%
passenger_RPR_by_city=passenger_RPR_by_city.merge(city,on='city_id',how='left')

# %%
passenger_RPR_by_city_plot=passenger_RPR_by_city.drop(columns=['city_id'])

# %%
passenger_RPR_by_city_plot
# Out:
#         RPR%      city_name
# 0  28.811272  Visakhapatnam
# 1  21.750782     Chandigarh
# 2  42.963123          Surat
# 3  30.793795       Vadodara
# 4  11.208195         Mysore
# 5  22.376614          Kochi
# 6  32.957829         Indore
# 7  18.329207         Jaipur
# 8  23.671272     Coimbatore
# 9  38.131873        Lucknow

# %%
plt.figure(figsize=(12,10))
sns.barplot(data=passenger_RPR_by_city_plot,x='city_name',y='RPR%')
plt.xlabel('City Name')
plt.ylabel('RPR%')
plt.title('Comparision of RPR% in different cities')
plt.xticks(rotation=45)
plt.show()

# %%
top_2_cities=passenger_RPR_by_city.sort_values(by='RPR%',ascending=False).head(2)
bottom_2_cities=passenger_RPR_by_city.sort_values(by='RPR%',ascending=True).head(2)

# %%
print("The top 2 cities with the highest RPR are:")
top_2_cities
# Out:
# The top 2 cities with the highest RPR are:
#   city_id       RPR% city_name
# 2    GJ01  42.963123     Surat
# 9    UP01  38.131873   Lucknow

# %%
print("The bottom 2 cities with the lowest RPR are:")
bottom_2_cities
# Out:
# The bottom 2 cities with the lowest RPR are:
#   city_id       RPR% city_name
# 4    KA01  11.208195    Mysore
# 7    RJ01  18.329207    Jaipur

# %% [markdown]
# The Repeat Passenger Rate (RPR%) analysis shows significant variations across cities and months. Surat has the highest RPR% of 42.96%, indicating strong customer loyalty, while Mysore has the lowest at 11.21%, showing challenges in retaining passengers. Lucknow and Indore also have relatively high RPR% at 38.13% and 32.96%, respectively, suggesting effective retention strategies in those cities.

# %%
#grouping by month
passenger_RPR_by_month=passenger_RPR.groupby('month')['RPR%'].mean().reset_index()
passenger_RPR_by_month
# Out:
#         month       RPR%
# 0  2024-01-01  19.718611
# 1  2024-02-01  21.815805
# 2  2024-03-01  25.980854
# 3  2024-04-01  29.954389
# 4  2024-05-01  34.218410
# 5  2024-06-01  30.908307

# %%
highest_rpr_month=passenger_RPR_by_month.sort_values(by='RPR%',ascending=False).head(2)
lowest_rpr_month=passenger_RPR_by_month.sort_values(by='RPR%',ascending=True).head(2)
print("Month with Highest RPR%:")
highest_rpr_month
# Out:
# Month with Highest RPR%:
#         month       RPR%
# 4  2024-05-01  34.218410
# 5  2024-06-01  30.908307

# %%
print("Month with Lowest RPR%:")
lowest_rpr_month
# Out:
# Month with Lowest RPR%:
#         month       RPR%
# 0  2024-01-01  19.718611
# 1  2024-02-01  21.815805

# %% [markdown]
# When analyzed by month, May 2024 has the highest RPR% of 34.22%, showing increased repeat usage, potentially due to favorable conditions or effective promotions. January 2024 has the lowest RPR% of 19.72%, which may indicate a slower start to the year for customer loyalty.
#
# **RECOMMENDATIONS:**
#
# Focus on cities like Mysore and Jaipur to enhance customer retention. This could be done through loyalty programs or discounts for repeat rides.
#
# For cities like Surat and Lucknow with high RPR%, analyze successful retention strategies and apply them to cities with lower retention rates.
#
#  Given the lower RPR% in January, consider running promotional campaigns or incentives during this period to encourage more repeat rides and balance demand throughout the year.

# %%
# Step 1: Calculate Average Fare per City
avg_fare_dist = trip_summary.groupby('city_id')['fare_amount'].mean().reset_index()
avg_fare_dist.rename(columns={'fare_amount': 'avg_fare'}, inplace=True)

# %%
# Calculate RPR% for each city
passenger['RPR%'] = (passenger['repeat_passengers'] / passenger['total_passengers']) * 100
rpr_df = passenger[['city_id', 'RPR%']]

# %%
merged_data = avg_fare_dist.merge(rpr_df, on='city_id', how='inner')

# %%
merged_data
# Out:
#    city_id    avg_fare  avg_distance      city_name       RPR%
# 0     AP01  282.672284     22.553938  Visakhapatnam  20.550111
# 1     AP01  282.672284     22.553938  Visakhapatnam  24.921136
# 2     AP01  282.672284     22.553938  Visakhapatnam  29.841578
# 3     AP01  282.672284     22.553938  Visakhapatnam  34.966514
# 4     AP01  282.672284     22.553938  Visakhapatnam  32.906574
# 5     AP01  282.672284     22.553938  Visakhapatnam  29.681717
# 6     CH01  283.686950     23.518714     Chandigarh  15.517241
# 7     CH01  283.686950     23.518714     Chandigarh  17.207989
# 8     CH01  283.686950     23.518714     Chandigarh  21.268293
# 9     CH01  283.686950     23.518714     Chandigarh  24.018265
# 10    CH01  283.686950     23.518714     Chandigarh  26.196269
# 11    CH01  283.686950     23.518714     Chandigarh  26.296633
# 12    GJ01  117.272925     10.997247          Surat  32.743363
# 13    GJ01  117.272925     10.997247          Surat  36.809644
# ...

# %%
correlation = merged_data[['avg_fare', 'RPR%']].corr()
print("Correlation between average fare and RPR%:")
print(correlation)
# Out:
# Correlation between average fare and RPR%:
#           avg_fare      RPR%
# avg_fare  1.000000 -0.554435
# RPR%     -0.554435  1.000000

# %% [markdown]
# **Factors influencing repeat passenger rates**

# %% [markdown]
# Based on the correlation analysis between average fare and Repeat Passenger Rate (RPR%), we observe a moderate negative correlation (-0.554). This suggests that cities with lower average fares tend to have higher RPR%, meaning passengers are more likely to use Goodcabs again when the fare is relatively lower.
#
# This implies that competitive pricing is an important factor contributing to higher repeat passenger rates. Offering lower fares appears to improve passenger loyalty, particularly in cities where price sensitivity may be higher due to socio-economic factors.
#
# Other potential factors influencing repeat passenger rates could include:
#
# Quality of Service: Consistent and high-quality service, such as on-time pickups, clean vehicles, and polite drivers, may contribute to increased repeat passenger rates.
#
# City Demographics: Cities with younger populations or lower income levels may be more price-sensitive, leading to higher repeat rates in response to competitive fares.
#
# Socioeconomic and Lifestyle Patterns: Cities with a higher concentration of working professionals or students may have higher repeat rates due to their frequent travel needs. Offering discounts or loyalty rewards could further enhance repeat usage in these areas.
#
# To boost repeat passenger rates across cities, strategies such as maintaining competitive pricing, improving quality of service, and offering loyalty programs could be effective, especially in cities where the RPR% is currently low.

# %% [markdown]
# **Tourism v/s Business Demand Impact**

# %% [markdown]
# Cities such as Jaipur, Kochi, and Lucknow experience significant demand in specific months such as February and May, which may coincide with local events, festivals, or holiday seasons, indicating a potential tourism influence. These peaks show that tourism seasons have a substantial impact on demand, particularly in tourism-oriented cities, opening up opportunity for specialized marketing initiatives to increase ridership during these periods.
#
# On the other hand, the weekday vs. weekend research reveals that places such as Jaipur and Kochi have much higher weekend trip counts, which is consistent with tourism activities, since visitors are more likely to explore on weekends. In contrast, places such as Lucknow have more weekday trips, which may be driven by business commuters.
#
#
# The repeat passenger rate (RPR%) varies by month, with higher rates reported in May and June, suggesting that Goodcabs' service quality during tourist seasons motivates passengers to return. Given these findings, adjusting marketing efforts to coincide with local events and presenting special weekend discounts or tourist packages may assist enhance travel volumes, particularly in tourism-focused cities during peak months. This data-driven strategy could greatly improve client acquisition and retention.

# %% [markdown]
# **Emerging Mobility Trends and Goodcabs Adaptation**

# %% [markdown]
# Emerging trends in the taxi service business, particularly in tier-2 cities, include the introduction of electric vehicles (EVs) and the usage of green energy. Customers are increasingly looking for environmentally friendly solutions, and governments are providing incentives for driving electric vehicles. Goodcabs could benefit from adding electric vehicles to their fleet, making their services more appealing to eco-conscious customers. This approach could also help them save money on fuel and position themselves as a more environmentally responsible corporation, providing them an advantage over competitors.

# %% [markdown]
# **PARTNERSHIP OPPORTUNITIES WITH LOCAL BUSINESS**

# %% [markdown]
# Partnering with local companies such as hotels, malls, and event locations could be an excellent way for Goodcabs to increase demand and client loyalty. These collaborations can help Goodcabs provide more convenient transportation options for tourists and shoppers, particularly in high-traffic regions. For example, cooperation with hotels can provide passengers with exclusive ride discounted prices, whilst partnerships with malls or event sites can provide discounts for attending events or making purchases. Such strategic relationships not only attract more clients, but also raise Goodcabs' visibility, making it easier to meet demand during peak times and increase ridership.

# %% [markdown]
# **DATA COLLECTION FOR ENHANCED DATA DRIVEN DECISIONS**

# %% [markdown]
# Customer Satisfaction Feedback - Reasons for high or low ratings.
#
# Customer Demographics - Age, income level, and other details to understand target audiences.
#
# Trip Preferences - Popular times, routes, and trip purposes.
#
# Vehicle Performance Data - Fuel efficiency, maintenance schedules.
#
# Driver Performance - Punctuality, customer ratings.
#
# Market Data - Competitor pricing and customer preferences for strategic adjustments.
